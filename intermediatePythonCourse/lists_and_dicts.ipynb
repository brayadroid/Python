# %%
def run():
  my_list = [1,"Hello",True,7.2]
  my_dict = {"FirstName":"Brayan","LastName":"Moya"}
  super_list_of_dict = [
                        {"FirstName":"Brayan","LastName":"Moya"},
                        {"FirstName":"Vannia","LastName":"Cisterna"},
                        {"FirstName":"Ronaldinho","LastName":"Gaucho"},
                        {"FirstName":"Alersis","LastName":"Sandwich"},
  ]
  super_dict_of_list = {
      "naturalNumbers":[1,2,3,4],
      "integerNumbers":[-1,-2,0,2,1],
      "floatingNumbers":[1.1,1.2,3.5,6.7]
  }

  #loop key and value at the same time
  for key, value in super_dict_of_list.items():
    print(key, "-", value)
  
  for l in super_list_of_dict:
    print(l)

# %%
if __name__ == '__main__':
  run()
# Out:
# naturalNumbers - [1, 2, 3, 4]
# integerNumbers - [-1, -2, 0, 2, 1]
# floatingNumbers - [1.1, 1.2, 3.5, 6.7]
# {'FirstName': 'Brayan', 'LastName': 'Moya'}
# {'FirstName': 'Vannia', 'LastName': 'Cisterna'}
# {'FirstName': 'Ronaldinho', 'LastName': 'Gaucho'}
# {'FirstName': 'Alersis', 'LastName': 'Sandwich'}
